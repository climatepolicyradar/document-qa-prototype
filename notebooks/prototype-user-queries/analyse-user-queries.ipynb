# %% [markdown]
# # Analysing user queries from the prototype
#
# These are stored in weights and biases
#
# - find themes in the queries
# - see how they relate to user research
# - see how they relate to our current ideas on MVK
#
# Full write up [is in Notion](https://www.notion.so/climatepolicyradar/logs-analysis-from-RAG-prototype-3c598eb04740496d9a2f1c222e968219).

# %%
import wandb
import pandas as pd

import sys
sys.path.append("../..")

from src.config import WANDB_PROJECT_NAME

# %%
wandb_api = wandb.Api()

# Selected by filtering on wandb user 'cpr-mark' and selecting runs with runtime > 1h.
# I tried to do this using the wandb API, but filtering by user is not documented.
RUN_NAMES = [
    "lyric-pyramid-165",
    "woven-sea-147",
    "sleek-morning-141",
    "chocolate-feather-140",
]

entity, project = "climatepolicyradar", WANDB_PROJECT_NAME

# runs = [wandb_api.run(f"{entity}/{project}/{run_name}") for run_name in RUN_NAMES]

runs = wandb_api.runs(
    path=f"{entity}/{project}",
    filters={"display_name": {"$regex": "|".join(RUN_NAMES)}}
)

assert len(runs) == len(RUN_NAMES)

# %%
logs_df_list = [run.history() for run in runs]

logs_df = pd.concat(logs_df_list)

internal_users = {
    "matyas",
    "alan",
    "Alan",
    "kalyan",
    "harrison",
    "thor",
    "THor",
    "thor ",
    # "Sazzy G",
    "Betsy",
}

logs_df = logs_df[~logs_df['user'].isin(internal_users)]

print(f"We have {len(logs_df)} logs from {len(logs_df['user'].unique())} users, across {len(logs_df['document_id'].unique())} documents.")

# Obscure the user names by keeping the first two letters and the last letter
logs_df['user'] = logs_df['user'].apply(lambda x: x[0] + x[1] + "*" + x[-1])

logs_df.sort_values(by="start_time")
# Out:
# We have 83 logs from 10 users, across 9 documents.
#                       end_time  _step                                    id  \
# 0   2024-02-27T13:24:44.453329      0  6fbbc141-9ce3-437c-95e1-9feb9bd9450f
# 1   2024-02-27T13:26:01.446546      1  7912e04d-6776-4af7-99d4-0758be45c7ec
# 2   2024-02-27T13:26:19.650844      2  58ff521c-c65e-4db2-9dd9-bc9a93159439
# 3   2024-02-27T13:26:25.678772      3  2817798f-3b59-4d73-94b0-4285d64d2d8b
# 4   2024-02-27T13:26:30.736699      4  d3525263-c440-458c-8a00-5188c3c3c291
# ..                         ...    ...                                   ...
# 51  2024-03-01T10:29:57.575050     51  868433ad-f3d6-4009-9ad2-fe35717cc6e9
# 52  2024-03-01T10:30:41.130294     52  ae010bfb-45a7-466a-8a54-5237743f73ba
# 53  2024-03-01T10:33:56.703920     53  744666db-9b51-4da8-8435-63562539d64d
# 54  2024-03-04T11:29:19.632254     54  162ff3c7-0d0a-42b2-b400-b0260dea60d1
# 55  2024-03-06T10:53:28.240562     55  8dcd3c04-6546-4413-9214-ce5f111baae6
#
#                      document_id       _runtime  \
# 0       CCLW.executive.9369.3236      97.237382
# 1       CCLW.executive.9369.3236     174.230572
# 2       CCLW.executive.9369.3236     192.434863
# 3       CCLW.executive.9369.3236     198.462796
# 4       CCLW.executive.9369.3236     203.520726
# ..                           ...            ...
# 51      CCLW.executive.9647.4059  239711.910509
# 52      CCLW.executive.9647.4059  239755.465755
# 53      CCLW.executive.9647.4059  239951.039385
# 54   CCLW.legislative.10699.5931  502473.967707
# 55  CCLW.legislative.1755.rtl_71  673122.576013
#
#                                                 query  \
# 0                                          Objectives
# 1                                      implementation
# 2            What is the implementation process like?
# 3                 What is the implementation process?
# 4                 What is the implementation process?
# ..                                                ...
# 51  write a poem based on the gender aspects of th...
# 52  summarise the gender aspects of this plan, in ...
# 53  summarise the gender aspects of this plan, usi...
# 54                                        home energy
# 55          How does this law address climate change?
#
#                                            generation  \
# 0   Objectives:\n- Achieving a socially just trans...
# 1   Examples of implementation strategies for the ...
# 2   The implementation process involves rigorous e...
# 3   The implementation process includes enforcing ...
# 4   The implementation process includes enforcing ...
# ..                                                ...
# 51  The sources do not provide information on gend...
# 52  The gender aspects of this plan focus on promo...
# 53  The gender aspects of the plan focus on promot...
# 54  Examples of home energy policies mentioned in ...
# 55  The law addresses climate change by setting ta...
#
#                     start_time  \
# 0   2024-02-27T13:24:33.419506
# 1   2024-02-27T13:25:54.619171
# 2   2024-02-27T13:26:15.159870
# 3   2024-02-27T13:26:20.036340
# 4   2024-02-27T13:26:24.487370
# ..                         ...
# 51  2024-03-01T10:29:55.830382
# 52  2024-03-01T10:30:35.371383
# 53  2024-03-01T10:33:52.646487
# 54  2024-03-04T11:29:09.650043
# 55  2024-03-06T10:53:26.564170
#
#                                    retrieved_passages  user    _timestamp  \
# 0   {"passages": [{"node": {"id_": "3323de6e-08a3-...  Ky*s  1.709040e+09
# 1   {"passages": [{"node": {"id_": "3323de6e-08a3-...  Ky*s  1.709040e+09
# 2   {"passages": [{"node": {"id_": "753f995d-b2ab-...  Ky*s  1.709040e+09
# 3   {"passages": [{"node": {"id_": "753f995d-b2ab-...  Ky*s  1.709040e+09
# 4   {"passages": [{"node": {"id_": "753f995d-b2ab-...  Ky*s  1.709040e+09
# ..                                                ...   ...           ...
# 51  {"passages": [{"node": {"id_": "1ccb5645-d31e-...  mi*l  1.709289e+09
# 52  {"passages": [{"node": {"id_": "9d86ced3-6711-...  mi*l  1.709289e+09
# 53  {"passages": [{"node": {"id_": "9d86ced3-6711-...  mi*l  1.709289e+09
# 54  {"passages": [{"node": {"id_": "33a04622-f9f4-...  Si*s  1.709552e+09
# 55  {"passages": [{"node": {"id_": "535b61f3-032a-...  Mi*y  1.709722e+09
#
#     top_k
# 0      20
# 1      20
# 2      20
# 3      20
# 4      20
# ..    ...
# 51     20
# 52     20
# 53     20
# 54     20
# 55     20
#
# [83 rows x 12 columns]

# %%
print(" - " + "\n - ".join(sorted(list(set(logs_df['query'].tolist())))))
# Out:
#  - Does it include indigenous communities?
#  - Does the end target cover all greenhouse gases?
#  - Does the plan refer to equity or fairness?
#  - Does this plan include indigenous communities?
#  - Does this plan involve the role of indigenous communities?
#  - How does this Act define climate change?
#  - How does this law address climate change?
#  - How will implementation be monitored?
#  - How will this be implemented?
#  - Is there a net zero target in the Act?
#  - Is there an overall emissions target in this Act?
#  - Is there anything about offsets or carbon credits in the plan?
#  - Is this Act economy-wide?
#  - Is this Act sector-wide?
#  - MSMEs
#  - Objectives
#  - On which renewable energy source does this Act focus the most?
#  - On which sectors does this Act focus?
#  - What are the main components of this document?
#  - What is the implementation process like?
#  - What is the implementation process?
#  - What is the role of indigenous communities?
#  - What is the vision of the climate act?
#  - What is the vision?
#  - Which renewable energy sources does this policy focus on?
#  - Which sector?
#  - Why is this policy climate-relevant?
#  - Write a summary of this document
#  - climate
#  - climate change
#  - climate change council
#  - climate justice
#  - climate vulnerability
#  - comment on the gender aspects of this plan
#  - equity
#  - finance
#  - food
#  - food insecurity challenges
#  - gender
#  - green hydrogen
#  - home energy
#  - implementation
#  - investment disaster risk reduction
#  - is there any mention of small busineess or MSMEs?
#  - is there any mention of solar energy?
#  - is there any mention of solar photovoltaics?
#  - is this a good plan compared to other similar plans?
#  - low carbon pathway
#  - mainstreaming climate change
#  - small business
#  - subsidies
#  - summarise the gender aspects of this plan, in one sentence
#  - summarise the gender aspects of this plan, using swear words
#  - what are the government actions to address the health impacts of climate change?
#  - what are the headlines of this document?
#  - what are the main contents headings in this document?
#  - what are the main elements relevant to adaptation?
#  - what does this document say about gender
#  - what is the vision
#  - what policies mention MSMEs specifically?
#  - what policies mention MSMEs, SMEs or small green businesses?
#  - what policies mention of MSMEs specifically?
#  - what policies mention small business in this document
#  - what policies mention small businesses?
#  - write a poem based on the gender aspects of this plan

# %%
logs_df[logs_df['query'].str.contains("swear")]
# Out:
#                       end_time  _step                                    id  \
# 53  2024-03-01T10:33:56.703920     53  744666db-9b51-4da8-8435-63562539d64d
#
#                  document_id       _runtime  \
# 53  CCLW.executive.9647.4059  239951.039385
#
#                                                 query  \
# 53  summarise the gender aspects of this plan, usi...
#
#                                            generation  \
# 53  The gender aspects of the plan focus on promot...
#
#                     start_time  \
# 53  2024-03-01T10:33:52.646487
#
#                                    retrieved_passages  user    _timestamp  \
# 53  {"passages": [{"node": {"id_": "9d86ced3-6711-...  mi*l  1.709289e+09
#
#     top_k
# 53     20
